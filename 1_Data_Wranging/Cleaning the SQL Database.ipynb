# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect("zippedData/im.db")

# %%
# %%bash
# sqlite3 zippedData/im.db
# .schema
# # just checking the .schema to get a better understanding of the data
# Out:
# CREATE TABLE IF NOT EXISTS "movie_basics" (
# "movie_id" TEXT,
#   "primary_title" TEXT,
#   "original_title" TEXT,
#   "start_year" INTEGER,
#   "runtime_minutes" REAL,
#   "genres" TEXT
# );
# CREATE TABLE IF NOT EXISTS "directors" (
# "movie_id" TEXT,
#   "person_id" TEXT
# );
# CREATE TABLE IF NOT EXISTS "known_for" (
# "person_id" TEXT,
#   "movie_id" TEXT
# );
# CREATE TABLE IF NOT EXISTS "movie_akas" (
# "movie_id" TEXT,
#   "ordering" INTEGER,
#   "title" TEXT,
#   "region" TEXT,
#   "language" TEXT,
#   "types" TEXT,
#   "attributes" TEXT,
#   "is_original_title" REAL
# );
# CREATE TABLE IF NOT EXISTS "movie_ratings" (
# "movie_id" TEXT,
#   "averagerating" REAL,
#   "numvotes" INTEGER
# );
# CREATE TABLE IF NOT EXISTS "persons" (
# "person_id" TEXT,
#   "primary_name" TEXT,
#   "birth_year" REAL,
#   "death_year" REAL,
#   "primary_profession" TEXT
# );
# CREATE TABLE IF NOT EXISTS "principals" (
# "movie_id" TEXT,
#   "ordering" INTEGER,
#   "person_id" TEXT,
#   "category" TEXT,
#   "job" TEXT,
#   "characters" TEXT
# );
# CREATE TABLE IF NOT EXISTS "writers" (
# "movie_id" TEXT,
#   "person_id" TEXT
# );

# %%
pd.read_sql("""
SELECT *
FROM movie_akas
JOIN movie_basics
USING (movie_id)
WHERE region IN ('US', "CA")
""",conn)
# checking movies and flittering for movies in the North American region
# Out:
#         movie_id  ordering                                        title  \
# 0      tt0369610        21                            Jurassic World 3D
# 1      tt0369610        28                             Monde jurassique
# 2      tt0369610        29                               Jurassic World
# 3      tt0369610         2                                     Ebb Tide
# 4      tt0369610        36                             Jurassic Park IV
# ...          ...       ...                                          ...
# 60356  tt9310460         6  Coconut the Little Dragon 2 Into the Jungle
# 60357  tt9358044         2                                  Hail Satan?
# 60358  tt9562694         5                                Alien Warfare
# 60359  tt9705860         1          Dusan Vukotic Croatian Oscar Winner
# 60360  tt9755806         1                                    Big Shark
#
#       region language        types          attributes  is_original_title  \
# 0         US     None         None         3-D version                0.0
# 1         CA       fr  imdbDisplay                None                0.0
# 2         US     None         None                None                0.0
# 3         US     None         None  fake working title                0.0
# 4         US     None      working                None                0.0
# ...      ...      ...          ...                 ...                ...
# 60356     US     None  imdbDisplay                None                0.0
# 60357     US     None  imdbDisplay                None                0.0
# 60358     US     None  imdbDisplay                None                0.0
# 60359     US     None  imdbDisplay                None                0.0
# 60360     US     None         None                None                0.0
#
#                                      primary_title  \
# 0                                   Jurassic World
# 1                                   Jurassic World
# 2                                   Jurassic World
# 3                                   Jurassic World
# 4                                   Jurassic World
# ...                                            ...
# 60356  Coconut the Little Dragon 2 Into the Jungle
# 60357                                  Hail Satan?
# 60358                                Alien Warfare
# 60359          Dusan Vukotic Croatian Oscar Winner
# 60360                                    Big Shark
#
#                                           original_title  start_year  \
# 0                                         Jurassic World        2015
# 1                                         Jurassic World        2015
# 2                                         Jurassic World        2015
# 3                                         Jurassic World        2015
# 4                                         Jurassic World        2015
# ...                                                  ...         ...
# 60356  Der kleine Drache Kokosnuss - Auf in den Dschu...        2018
# 60357                                        Hail Satan?        2019
# 60358                                      Alien Warfare        2019
# 60359                    Dusan Vukotic hrvatski okarovac        2011
# 60360                                          Big Shark        2019
#
#        runtime_minutes                      genres
# 0                124.0     Action,Adventure,Sci-Fi
# 1                124.0     Action,Adventure,Sci-Fi
# 2                124.0     Action,Adventure,Sci-Fi
# 3                124.0     Action,Adventure,Sci-Fi
# 4                124.0     Action,Adventure,Sci-Fi
# ...                ...                         ...
# 60356              NaN  Adventure,Animation,Comedy
# 60357             95.0                 Documentary
# 60358             88.0               Action,Sci-Fi
# 60359             55.0                 Documentary
# 60360              NaN                      Horror
#
# [60361 rows x 13 columns]

# %%
director_df = pd.read_sql("""
SELECT movie_id, primary_name as director, primary_title, genres, start_year,averagerating,region

FROM directors
JOIN persons 
USING (person_id)

JOIN movie_basics
USING (movie_id)



JOIN movie_akas
USING (movie_id)

JOIN movie_ratings
USING (movie_id)

WHERE region IN ('US',"CA")

GROUP BY movie_id

""",conn)



# First i am joining directors and person to get the directors name
# then i am joining it with the movie_basics to get movie name, based on the id
# also making sure I have the region 
# and the ratings
#  getting the region based the north american region, because we are in the US and we share common thing with CA
# grouping by movie_id for less duplicates

# %%
writer_df = pd.read_sql("""
SELECT  movie_id, primary_name as writers
FROM persons 
JOIN writers
USING (person_id)

JOIN movie_basics
USING (movie_id)


""",conn)
# also want to get the writer for each movie

# %%
director_df.set_index('movie_id', inplace=True)

# %%
writer_df.set_index('movie_id', inplace=True)

# %%
df = director_df.join(writer_df, how='inner')
# joining the directors and writer dataset, to have both directors and writer in the same dataset
# that is why I set the index to movie_id so join will be easier

# %%
df.reset_index(inplace=True)
# resetting the index

# %%
df.head()
# taking a look at the frame
# You have to save this dataframe
# Out:
#     movie_id          director                       primary_title  \
# 0  tt0069049      Orson Welles          The Other Side of the Wind
# 1  tt0069049      Orson Welles          The Other Side of the Wind
# 2  tt0137204  Anthony Harrison                     Joe Finds Grace
# 3  tt0159369   John Mulholland  Cooper and Hemingway: The True Gen
# 4  tt0192528       Stuart Paul                       Heaven & Hell
#
#                        genres  start_year  averagerating region  \
# 0                       Drama        2018            6.9     US
# 1                       Drama        2018            6.9     US
# 2  Adventure,Animation,Comedy        2017            8.1     CA
# 3                 Documentary        2013            7.6     US
# 4                       Drama        2018            4.0     US
#
#             writers
# 0         Oja Kodar
# 1      Orson Welles
# 2  Anthony Harrison
# 3   John Mulholland
# 4       Stuart Paul

# %%
df.isna().sum()
# checking for null values
# Out:
# movie_id           0
# director           0
# primary_title      0
# genres           166
# start_year         0
# averagerating      0
# region             0
# writers            0
# dtype: int64

# %%
df.shape
# Out:
# (77360, 8)

# %%
df.dropna(subset=["genres"], inplace=True)
# because the null in genres is low, I am going to drop them based on the generes row

# %%
df.shape
# Out:
# (77194, 8)

# %%
dup_bool_series = df.duplicated()
dup_bool_series.sum()
# checking for duplicates in the dataframe
# I dont want duplicates
# Out:
# 30374

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# still have a large dataset
# Out:
# (46820, 8)

# %%
df.isna().sum()
# Out:
# movie_id         0
# director         0
# primary_title    0
# genres           0
# start_year       0
# averagerating    0
# region           0
# writers          0
# dtype: int64

# %%
df
# Out:
#         movie_id          director                       primary_title  \
# 0      tt0069049      Orson Welles          The Other Side of the Wind
# 1      tt0069049      Orson Welles          The Other Side of the Wind
# 2      tt0137204  Anthony Harrison                     Joe Finds Grace
# 3      tt0159369   John Mulholland  Cooper and Hemingway: The True Gen
# 4      tt0192528       Stuart Paul                       Heaven & Hell
# ...          ...               ...                                 ...
# 77355  tt9825006    Rémi St-Michel                 Avant qu'on explose
# 77356  tt9845398      Lucio Castro                  End of the Century
# 77357  tt9852644       Loïc Darses                   La Fin des terres
# 77358  tt9866344   Adib Alkhalidey                       Mon Ami Walid
# 77359  tt9866344   Adib Alkhalidey                       Mon Ami Walid
#
#                            genres  start_year  averagerating region  \
# 0                           Drama        2018            6.9     US
# 1                           Drama        2018            6.9     US
# 2      Adventure,Animation,Comedy        2017            8.1     CA
# 3                     Documentary        2013            7.6     US
# 4                           Drama        2018            4.0     US
# ...                           ...         ...            ...    ...
# 77355                      Comedy        2019            6.9     CA
# 77356                       Drama        2019            7.2     US
# 77357                 Documentary        2019            7.0     CA
# 77358                Comedy,Drama        2019            5.7     CA
# 77359                Comedy,Drama        2019            5.7     CA
#
#                  writers
# 0              Oja Kodar
# 1           Orson Welles
# 2       Anthony Harrison
# 3        John Mulholland
# 4            Stuart Paul
# ...                  ...
# 77355  Eric K. Boulianne
# 77356       Lucio Castro
# 77357        Loïc Darses
# 77358    Adib Alkhalidey
# 77359     Julien Lacroix
#
# [46820 rows x 8 columns]

# %% [markdown]
# # Based on this dataframe, the question we can ask to solve are
#
# ## 1. What is the best genre based on average_rating per year, in the US and CA regions, is there a trend?
#
# (seaborn is probably best for the 1st question, x=year, y=average_rating, hue = genre)
# you have to group the genere the with the average_rating for this to work
#
# ## 2. Which writer wrote the best movie based on average_rating per genres, in the US and CA regions?
